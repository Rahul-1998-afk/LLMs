# %%
# !pip install openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.6 MB/s eta 0:00:00
# ...

# %%
import openai as ai
import re

# %%
openai_api_key="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"
ai.api_key = openai_api_key

# %%
def chat_completion_ai(message, model="gpt-3.5-turbo", openai_api_key=None, max_length=None):
  try:
    ## TODO find max length issue
    response = ai.chat.completions.create(
        model=model,
        messages=message,
        max_tokens=max_length,  # default max length of output is 100
        temperature=0
    )

    output = ''
    for choice in response.choices:
        output += choice.message.content.strip("/n")

    # log_obj.info("OpenAI results: " + str(output))

    return output
  except:
    import traceback as tb
    tb.print_exc()

# %%
models = ai.models.list()
for model in models:
  print(model.id)
# Out:
# dall-e-3
# whisper-1
# gpt-4o-2024-05-13
# davinci-002
# gpt-4o
# dall-e-2
# gpt-3.5-turbo-16k
# tts-1-hd-1106
# tts-1-hd
# gpt-4
# gpt-4-0613
# gpt-4-turbo-2024-04-09
# gpt-3.5-turbo-1106
# gpt-4-turbo
# gpt-3.5-turbo-instruct-0914
# gpt-3.5-turbo-instruct
# tts-1
# gpt-3.5-turbo
# gpt-3.5-turbo-0301
# babbage-002
# gpt-4-1106-preview
# gpt-4-0125-preview
# tts-1-1106
# gpt-3.5-turbo-0125
# gpt-4-turbo-preview
# text-embedding-3-large
# text-embedding-3-small
# gpt-3.5-turbo-0613
# text-embedding-ada-002
# gpt-4-1106-vision-preview
# gpt-4-vision-preview
# gpt-3.5-turbo-16k-0613

# %%
query = "Which AI model you are using currently?"
message = [
    {"role": "user", "content": str(query)}
    ]
result = chat_completion_ai(message, model="gpt-4o")
print(result)
# Out:
# I'm based on OpenAI's GPT-4 architecture. How can I assist you today?
